# %%
# Modulimporte
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

#from ipywidgets import IntSlider, FloatSlider

# %%
taxis = sns.load_dataset('taxis')

# %%
# Als csv speichern
taxis.to_csv("taxis.csv", index=False)

# %%
# Boxplot erstellen
# plt.figure()
sns.boxplot(x="total", data=taxis)
plt.title('Boxplot "total"')
# plt.show()
# Out:
# Text(0.5, 1.0, 'Boxplot "total"')

# %%
sns.boxplot(data=taxis["total"])
plt.title('Boxplot "total"')
# Out:
# Text(0.5, 1.0, 'Boxplot "total"')
